# %%
import pandas as pd 
df = pd.read_csv("IRIS.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
freq= df['petal_width'].value_counts()
print(freq)
# Out:
# petal_width
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.duplicated().sum()
# Out:
# 3

# %% [markdown]
# first train test split

# %%
x=df[['sepal_length',	'sepal_width'	,'petal_length', 	'petal_width']]
y=df['species']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
y_test.shape
# Out:
# (30,)

# %%
x_train.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 22           4.6          3.6           1.0          0.2
# 15           5.7          4.4           1.5          0.4
# 65           6.7          3.1           4.4          1.4
# 11           4.8          3.4           1.6          0.2
# 42           4.4          3.2           1.3          0.2

# %%
#standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()
scale.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scale= scale.transform(x_train)
x_test_scale=scale.transform(x_test)

# %%
x_train_scale.shape
# Out:
# (120, 4)

# %%
import numpy as np
x_train.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 22           4.6          3.6           1.0          0.2
# 15           5.7          4.4           1.5          0.4
# 65           6.7          3.1           4.4          1.4
# 11           4.8          3.4           1.6          0.2
# 42           4.4          3.2           1.3          0.2

# %%
x_train_scale = pd.DataFrame(x_train_scale, columns=x_train.columns)
x_test_scale = pd.DataFrame(x_test_scale, columns=x_test.columns)

# %%
x_train.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width
# 22            4.6          3.6           1.0          0.2
# 15            5.7          4.4           1.5          0.4
# 65            6.7          3.1           4.4          1.4
# 11            4.8          3.4           1.6          0.2
# 42            4.4          3.2           1.3          0.2
# ..            ...          ...           ...          ...
# 71            6.1          2.8           4.0          1.3
# 106           4.9          2.5           4.5          1.7
# 14            5.8          4.0           1.2          0.2
# 92            5.8          2.6           4.0          1.2
# 102           7.1          3.0           5.9          2.1
#
# [120 rows x 4 columns]>

# %%
x_train_scale.describe()
# Out:
#        sepal_length   sepal_width  petal_length   petal_width
# count  1.200000e+02  1.200000e+02  1.200000e+02  1.200000e+02
# mean   6.513308e-16  7.549517e-16  1.924387e-16  1.443290e-16
# std    1.004193e+00  1.004193e+00  1.004193e+00  1.004193e+00
# min   -1.839628e+00 -2.378896e+00 -1.563987e+00 -1.442764e+00
# 25%   -8.644522e-01 -5.792584e-01 -1.277280e+00 -1.176203e+00
# 50%   -7.212234e-02 -1.293490e-01  2.996089e-01  1.566049e-01
# 75%    7.202076e-01  6.017538e-01  7.870110e-01  8.230088e-01
# max    2.304867e+00  3.020017e+00  1.704474e+00  1.755974e+00

# %%
fig, (ax1, ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title('before scaling')
sns.kdeplot(x_train['sepal_width'],ax=ax1)
sns.kdeplot(x_train['petal_width'],ax=ax1)
fig, (ax1, ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax2.set_title('after scaling')
sns.kdeplot(x_train_scale['sepal_width'],ax=ax2)
sns.kdeplot(x_train_scale['petal_width'],ax=ax2)
plt.show()

# %%
fig, (ax1, ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title('before scaling')
sns.kdeplot(x_train['sepal_length'],ax=ax1)
sns.kdeplot(x_train['petal_width'],ax=ax1)
fig, (ax1, ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax2.set_title('after scaling')
sns.kdeplot(x_train_scale['sepal_length'],ax=ax2)
sns.kdeplot(x_train_scale['petal_width'],ax=ax2)
plt.show()

# %%
fig, (ax1, ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title('before scaling')
sns.kdeplot(x_train['sepal_length'],ax=ax1)
sns.kdeplot(x_train['petal_length'],ax=ax1)
fig, (ax1, ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax2.set_title('after scaling')
sns.kdeplot(x_train_scale['sepal_length'],ax=ax2)
sns.kdeplot(x_train_scale['petal_length'],ax=ax2)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
#train on unscaled data

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)  
y_pred_actual=lr.predict(x_test)

# %%
lr_scale=LogisticRegression()
lr_scale.fit(x_train_scale,y_train)
y_pred=lr_scale.predict(x_test_scale)

# %%
print("Accuracy (Unscaled Data):", accuracy_score(y_test, y_pred_actual))
print("Accuracy (Scaled Data):", accuracy_score(y_test, y_pred))
# Out:
# Accuracy (Unscaled Data): 1.0
# Accuracy (Scaled Data): 1.0

# %%
print("Test set size:", len(y_test))
print("Predictions:", y_pred[:10])
print("Actual:", y_test[:10].values)
# Out:
# Test set size: 30
# Predictions: ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor']
# Actual: ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
dt_scaled.fit(x_train_scale,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)
y_pred_scale = dt_scaled.predict(x_test_scale)

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scale))
# Out:
# Actual 1.0
# Scaled 1.0

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_scale, y_train)
y_pred_knn = knn.predict(x_test_scale)
print("\nKNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 1.0
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ritik'
